# %%
# %pylab inline
from pygadgetreader import readsnap
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# pygagdgetreader repository with documentation:
#
# https://bitbucket.org/rthompson/pygadgetreader
#
# bellow its a simple example of how to use it.

# %%
# don't put the extension of the snapshot pygadgetreader indetify the extension
DM_pos = readsnap('../data/MWfLMC6H1_000', 'pos', 'dm') 
DM_vel = readsnap('../data/MWfLMC6H1_000', 'vel', 'dm')
DM_pot = readsnap('../data/MWfLMC6H1_000', 'pot', 'dm')


disk_pos = readsnap('../data/MWfLMC6H1_000', 'pos', 'disk')
disk_vel = readsnap('../data/MWfLMC6H1_000', 'vel', 'disk')
disk_pot = readsnap('../data/MWfLMC6H1_000', 'pot', 'disk')
# Out:
# Returning DM    Positions
# Returning DM    Velocities
# Returning DM    Potential
# Returning DISK  Positions
# Returning DISK  Velocities
# Returning DISK  Potential

# %%
figsize(5,5)
scatter(DM_pos[:,0], DM_pos[:,1], s=0.1)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:549: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
